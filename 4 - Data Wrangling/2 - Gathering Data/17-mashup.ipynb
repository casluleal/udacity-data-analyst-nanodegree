# %% [markdown]
# ## Quiz

# %%
import pandas as pd
import wptools
import os
import requests
from PIL import Image
from io import BytesIO

# %%
title_list = [
 'The_Wizard_of_Oz_(1939_film)',
 'Citizen_Kane',
 'The_Third_Man',
 'Get_Out_(film)',
 'Mad_Max:_Fury_Road',
 'The_Cabinet_of_Dr._Caligari',
 'All_About_Eve',
 'Inside_Out_(2015_film)',
 'The_Godfather',
 'Metropolis_(1927_film)',
 'E.T._the_Extra-Terrestrial',
 'Modern_Times_(film)',
 'It_Happened_One_Night',
 "Singin'_in_the_Rain",
 'Boyhood_(film)',
 'Casablanca_(film)',
 'Moonlight_(2016_film)',
 'Psycho_(1960_film)',
 'Laura_(1944_film)',
 'Nosferatu',
 'Snow_White_and_the_Seven_Dwarfs_(1937_film)',
 "A_Hard_Day%27s_Night_(film)",
 'La_Grande_Illusion',
 'North_by_Northwest',
 'The_Battle_of_Algiers',
 'Dunkirk_(2017_film)',
 'The_Maltese_Falcon_(1941_film)',
 'Repulsion_(film)',
 '12_Years_a_Slave_(film)',
 'Gravity_(2013_film)',
 'Sunset_Boulevard_(film)',
 'King_Kong_(1933_film)',
 'Spotlight_(film)',
 'The_Adventures_of_Robin_Hood',
 'Rashomon',
 'Rear_Window',
 'Selma_(film)',
 'Taxi_Driver',
 'Toy_Story_3',
 'Argo_(2012_film)',
 'Toy_Story_2',
 'The_Big_Sick',
 'Bride_of_Frankenstein',
 'Zootopia',
 'M_(1931_film)',
 'Wonder_Woman_(2017_film)',
 'The_Philadelphia_Story_(film)',
 'Alien_(film)',
 'Bicycle_Thieves',
 'Seven_Samurai',
 'The_Treasure_of_the_Sierra_Madre_(film)',
 'Up_(2009_film)',
 '12_Angry_Men_(1957_film)',
 'The_400_Blows',
 'Logan_(film)',
 'All_Quiet_on_the_Western_Front_(1930_film)',
 'Army_of_Shadows',
 'Arrival_(film)',
 'Baby_Driver',
 'A_Streetcar_Named_Desire_(1951_film)',
 'The_Night_of_the_Hunter_(film)',
 'Star_Wars:_The_Force_Awakens',
 'Manchester_by_the_Sea_(film)',
 'Dr._Strangelove',
 'Frankenstein_(1931_film)',
 'Vertigo_(film)',
 'The_Dark_Knight_(film)',
 'Touch_of_Evil',
 'The_Babadook',
 'The_Conformist_(film)',
 'Rebecca_(1940_film)',
 "Rosemary%27s_Baby_(film)",
 'Finding_Nemo',
 'Brooklyn_(film)',
 'The_Wrestler_(2008_film)',
 'The_39_Steps_(1935_film)',
 'L.A._Confidential_(film)',
 'Gone_with_the_Wind_(film)',
 'The_Good,_the_Bad_and_the_Ugly',
 'Skyfall',
 'Rome,_Open_City',
 'Tokyo_Story',
 'Hell_or_High_Water_(film)',
 'Pinocchio_(1940_film)',
 'The_Jungle_Book_(2016_film)',
 'La_La_Land_(film)',
 'Star_Trek_(film)',
 'High_Noon',
 'Apocalypse_Now',
 'On_the_Waterfront',
 'The_Wages_of_Fear',
 'The_Last_Picture_Show',
 'Harry_Potter_and_the_Deathly_Hallows_–_Part_2',
 'The_Grapes_of_Wrath_(film)',
 'Roman_Holiday',
 'Man_on_Wire',
 'Jaws_(film)',
 'Toy_Story',
 'The_Godfather_Part_II',
 'Battleship_Potemkin'
]

# %%
folder_name = 'bestofrt_posters'
# Make directory if it doesn't already exist
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %% [markdown]
# #### Note: the cell below, if correctly implemented, will likely take ~5 minutes to run.

# %%
# List of dictionaries to build and convert to a DataFrame later
df_list = []
image_errors = {}
for title in title_list:
    try:
        # This cell is slow so print ranking to gauge time remaining
        ranking = title_list.index(title) + 1
        print(ranking)
        page = wptools.page(title, silent=True)
        # Your code here (three lines)
        images = page.get().data['image']
        # First image is usually the poster
        first_image_url = images[0]['url']
        r = requests.get(first_image_url)
        # Download movie poster image
        i = Image.open(BytesIO(r.content))
        image_file_format = first_image_url.split('.')[-1]
        i.save(folder_name + "/" + str(ranking) + "_" + title + '.' + image_file_format)
        # Append to list of dictionaries
        df_list.append({'ranking': int(ranking),
                        'title': title,
                        'poster_url': first_image_url})
    
    # Not best practice to catch all exceptions but fine for this short script
    except Exception as e:
        print(str(ranking) + "_" + title + ": " + str(e))
        image_errors[str(ranking) + "_" + title] = images
# Out:
# 1
# 1_The_Wizard_of_Oz_(1939_film): cannot identify image file <_io.BytesIO object at 0x7fa1180a03b0>
# 2
# 2_Citizen_Kane: cannot identify image file <_io.BytesIO object at 0x7fa119ec9360>
# 3
# 3_The_Third_Man: cannot identify image file <_io.BytesIO object at 0x7fa0c806e360>
# 4
# 5
# 6
# 6_The_Cabinet_of_Dr._Caligari: cannot identify image file <_io.BytesIO object at 0x7fa0b80d23b0>
# 7
# 7_All_About_Eve: cannot identify image file <_io.BytesIO object at 0x7fa11ab65c20>
# 8
# 9
# 10
# 11
# 12
# 13
# 13_It_Happened_One_Night: cannot identify image file <_io.BytesIO object at 0x7fa11ac2d4a0>
# 14
# 14_Singin'_in_the_Rain: cannot identify image file <_io.BytesIO object at 0x7fa0b80ca720>
# 15
# 15_Boyhood_(film): 'image'
# 16
# 17
# 18
# 18_Psycho_(1960_film): cannot identify image file <_io.BytesIO object at 0x7fa0d813d6d0>
# 19
# 19_Laura_(1944_film): cannot identify image file <_io.BytesIO object at 0x7fa11ab65c20>
# 20
# 21
# 22
# API error: {'code': 'invalidtitle', 'info': 'Bad title "A_Hard_Day%27s_Night_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 22_A_Hard_Day%27s_Night_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=A_Hard_Day%2527s_Night_%28film%29
# 23
# 24
# 24_North_by_Northwest: cannot identify image file <_io.BytesIO object at 0x7fa11ab88590>
# 25
# 26
# 27
# 27_The_Maltese_Falcon_(1941_film): cannot identify image file <_io.BytesIO object at 0x7fa0b80e1e50>
# 28
# 29
# 30
# 31
# 31_Sunset_Boulevard_(film): cannot identify image file <_io.BytesIO object at 0x7fa0d8361f40>
# 32
# 32_King_Kong_(1933_film): cannot identify image file <_io.BytesIO object at 0x7fa11a7fd630>
# 33
# 34
# 34_The_Adventures_of_Robin_Hood: cannot identify image file <_io.BytesIO object at 0x7fa0b80b6f90>
# 35
# 35_Rashomon: cannot identify image file <_io.BytesIO object at 0x7fa0d8383360>
# 36
# 36_Rear_Window: cannot identify image file <_io.BytesIO object at 0x7fa0b80ca1d0>
# 37
# 38
# 39
# 40
# 41
# 42
# 43
# 43_Bride_of_Frankenstein: cannot identify image file <_io.BytesIO object at 0x7fa0d813c0e0>
# 44
# 45
# 46
# 47
# 47_The_Philadelphia_Story_(film): cannot identify image file <_io.BytesIO object at 0x7fa0d813cef0>
# 48
# 49
# 50
# 50_Seven_Samurai: cannot identify image file <_io.BytesIO object at 0x7fa0d8321d60>
# 51
# 51_The_Treasure_of_the_Sierra_Madre_(film): cannot identify image file <_io.BytesIO object at 0x7fa0d8321b30>
# 52
# 53
# 53_12_Angry_Men_(1957_film): cannot identify image file <_io.BytesIO object at 0x7fa0d83211d0>
# 54
# 54_The_400_Blows: cannot identify image file <_io.BytesIO object at 0x7fa0b80e63b0>
# 55
# 56
# 57
# 58
# 59
# 60
# 60_A_Streetcar_Named_Desire_(1951_film): cannot identify image file <_io.BytesIO object at 0x7fa11ab889f0>
# 61
# 61_The_Night_of_the_Hunter_(film): cannot identify image file <_io.BytesIO object at 0x7fa11ac26cc0>
# 62
# 63
# 64
# 65
# 65_Frankenstein_(1931_film): cannot identify image file <_io.BytesIO object at 0x7fa11aac62c0>
# 66
# 66_Vertigo_(film): cannot identify image file <_io.BytesIO object at 0x7fa11ab814f0>
# 67
# 68
# 68_Touch_of_Evil: cannot identify image file <_io.BytesIO object at 0x7fa0d8366f90>
# 69
# 70
# 70_The_Conformist_(film): cannot identify image file <_io.BytesIO object at 0x7fa0e84689a0>
# 71
# 71_Rebecca_(1940_film): cannot identify image file <_io.BytesIO object at 0x7fa0b80d9540>
# 72
# API error: {'code': 'invalidtitle', 'info': 'Bad title "Rosemary%27s_Baby_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/postorius/lists/mediawiki-api-announce.lists.wikimedia.org/&gt; for notice of API deprecations and breaking changes.'}
# 72_Rosemary%27s_Baby_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=Rosemary%2527s_Baby_%28film%29
# 73
# 74
# 75
# 76
# 77
# 78
# 78_Gone_with_the_Wind_(film): cannot identify image file <_io.BytesIO object at 0x7fa0d8015c20>
# 79
# 80
# 81
# 82
# 82_Tokyo_Story: cannot identify image file <_io.BytesIO object at 0x7fa0d803f5e0>
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 90_On_the_Waterfront: cannot identify image file <_io.BytesIO object at 0x7fa0d813db80>
# 91
# 91_The_Wages_of_Fear: cannot identify image file <_io.BytesIO object at 0x7fa0b80ec680>
# 92
# 93
# 94
# 94_The_Grapes_of_Wrath_(film): cannot identify image file <_io.BytesIO object at 0x7fa0d83199f0>
# 95
# 95_Roman_Holiday: cannot identify image file <_io.BytesIO object at 0x7fa0c806ee00>
# 96
# 97
# 98
# 99
# 100

# %% [markdown]
# One you have completed the above code requirements, read and run the three cells below and interpret their output.

# %%
for key in image_errors.keys():
    print(key)
# Out:
# 1_The_Wizard_of_Oz_(1939_film)
# 2_Citizen_Kane
# 3_The_Third_Man
# 6_The_Cabinet_of_Dr._Caligari
# 7_All_About_Eve
# 13_It_Happened_One_Night
# 14_Singin'_in_the_Rain
# 15_Boyhood_(film)
# 18_Psycho_(1960_film)
# 19_Laura_(1944_film)
# 22_A_Hard_Day%27s_Night_(film)
# 24_North_by_Northwest
# 27_The_Maltese_Falcon_(1941_film)
# 31_Sunset_Boulevard_(film)
# 32_King_Kong_(1933_film)
# 34_The_Adventures_of_Robin_Hood
# 35_Rashomon
# 36_Rear_Window
# 43_Bride_of_Frankenstein
# 47_The_Philadelphia_Story_(film)
# 50_Seven_Samurai
# 51_The_Treasure_of_the_Sierra_Madre_(film)
# 53_12_Angry_Men_(1957_film)
# 54_The_400_Blows
# 60_A_Streetcar_Named_Desire_(1951_film)
# 61_The_Night_of_the_Hunter_(film)
# 65_Frankenstein_(1931_film)
# 66_Vertigo_(film)
# 68_Touch_of_Evil
# 70_The_Conformist_(film)
# 71_Rebecca_(1940_film)
# 72_Rosemary%27s_Baby_(film)
# 78_Gone_with_the_Wind_(film)
# 82_Tokyo_Story
# 90_On_the_Waterfront
# 91_The_Wages_of_Fear
# 94_The_Grapes_of_Wrath_(film)
# 95_Roman_Holiday

# %%
pg = wptools.page("Boyhood_(2014_film)", silent=True).get()
pg.data['image'][0]['url']
# Out:
# 'https://upload.wikimedia.org/wikipedia/en/a/a6/Boyhood_%282014%29.png'

# %%
# Inspect unidentifiable images and download them individually
for rank_title, images in image_errors.items():
    try:
        if rank_title == '1_The_Wizard_of_Oz_(1939_film)':
            url = 'https://upload.wikimedia.org/wikipedia/commons/6/69/Wizard_of_oz_movie_poster.jpg'
        if rank_title == '2_Citizen_Kane':
            url = 'https://upload.wikimedia.org/wikipedia/commons/c/c0/Citizen_Kane_poster%2C_1941_%28Style_B%2C_unrestored%29.jpg'
        if rank_title == '3_The_Third_Man':
            url = 'https://upload.wikimedia.org/wikipedia/commons/7/77/The_Third_Man_%281949_American_theatrical_poster%29.jpg'
        if rank_title == '6_The_Cabinet_of_Dr._Caligari':
            url = 'https://upload.wikimedia.org/wikipedia/en/2/2f/The_Cabinet_of_Dr._Caligari_poster.jpg'
        if rank_title == '7_All_About_Eve':
            url = 'https://upload.wikimedia.org/wikipedia/commons/a/a7/All_About_Eve_%281950_poster_-_retouch%29.jpg'
        if rank_title == '13_It_Happened_One_Night':
            url = 'https://upload.wikimedia.org/wikipedia/commons/d/dc/It-happened-one-night-poster.jpg'
        if rank_title == "14_Singin'_in_the_Rain":
            url = 'https://upload.wikimedia.org/wikipedia/commons/5/5d/Singin%27_in_the_Rain_%281952_poster%29.jpg'
        if rank_title == '15_Boyhood_(film)':
            url = 'https://upload.wikimedia.org/wikipedia/en/a/a6/Boyhood_%282014%29.png'
        if rank_title == '22_A_Hard_Day%27s_Night_(film)':
            url = 'https://upload.wikimedia.org/wikipedia/en/4/47/A_Hard_Days_night_movieposter.jpg'
        if rank_title == '53_12_Angry_Men_(1957_film)':
            url = 'https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg'
        if rank_title == '72_Rosemary%27s_Baby_(film)':
            url = 'https://upload.wikimedia.org/wikipedia/en/e/ef/Rosemarys_baby_poster.jpg'
        if rank_title == '93_Harry_Potter_and_the_Deathly_Hallows_–_Part_2':
            url = 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg'

        if rank_title[1] == '_':
            title = rank_title[2:]
        else:
            title = rank_title[3:]

        df_list.append({'ranking': int(title_list.index(title) + 1),
                        'title': title,
                        'poster_url': url})

        r = requests.get(url)
        # Download movie poster image
        i = Image.open(BytesIO(r.content))
        image_file_format = url.split('.')[-1]
        i.save(folder_name + "/" + rank_title + '.' + image_file_format)
    
    except Exception as e:
        print(str(e))
        print(url)
# Out:
# cannot identify image file <_io.BytesIO object at 0x7fa11bc53950>
# https://upload.wikimedia.org/wikipedia/commons/6/69/Wizard_of_oz_movie_poster.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bbced60>
# https://upload.wikimedia.org/wikipedia/commons/7/77/The_Third_Man_%281949_American_theatrical_poster%29.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bbcec70>
# https://upload.wikimedia.org/wikipedia/en/2/2f/The_Cabinet_of_Dr._Caligari_poster.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bc53950>
# https://upload.wikimedia.org/wikipedia/commons/a/a7/All_About_Eve_%281950_poster_-_retouch%29.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bc534a0>
# https://upload.wikimedia.org/wikipedia/commons/d/dc/It-happened-one-night-poster.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bc5ed60>
# https://upload.wikimedia.org/wikipedia/commons/5/5d/Singin%27_in_the_Rain_%281952_poster%29.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd80400>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd80c20>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd809a0>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd807c0>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd80400>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd80c20>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd80ea0>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd80040>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg
# cannot identify image file <_io.BytesIO object at 0x7fa11bd80400>
# https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg

# %%
# Create DataFrame from list of dictionaries
df = pd.DataFrame(df_list, columns = ['ranking', 'title', 'poster_url'])
df = df.sort_values('ranking').reset_index(drop=True)
df
# Out:
#      ranking                         title  \
# 0          1  The_Wizard_of_Oz_(1939_film)
# 1          1  The_Wizard_of_Oz_(1939_film)
# 2          1  The_Wizard_of_Oz_(1939_film)
# 3          2                  Citizen_Kane
# 4          2                  Citizen_Kane
# ..       ...                           ...
# 134       96                   Man_on_Wire
# 135       97                   Jaws_(film)
# 136       98                     Toy_Story
# 137       99         The_Godfather_Part_II
# 138      100           Battleship_Potemkin
#
#                                             poster_url
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 134  https://upload.wikimedia.org/wikipedia/en/5/54...
# 135  https://upload.wikimedia.org/wikipedia/en/e/eb...
# 136  https://upload.wikimedia.org/wikipedia/en/1/13...
# 137  https://upload.wikimedia.org/wikipedia/en/0/03...
# 138  https://upload.wikimedia.org/wikipedia/commons...
#
# [139 rows x 3 columns]

# %%
df.iloc[136]
# Out:
# ranking                                                      98
# title                                                 Toy_Story
# poster_url    https://upload.wikimedia.org/wikipedia/en/1/13...
# Name: 136, dtype: object
